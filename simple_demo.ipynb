# %% [markdown]
# # Beam bending calculator
#
# * Leave *lines 1-6 and 20-21 as they are*; they ensure that all necessary modules are imported and active.
#
# * Whatever code is written to the right of **#** (the numeral sign) is a comment. These comments are not executed, so you can safely ignore or delete them.
#
# The current code reproduces [this example](https://www.mathalino.com/reviewer/mechanics-and-strength-of-materials/solution-to-problem-448-relationship-between-load-shear).

# %%
# Initialization (leave this section as it is, unless you know what you are doing)
# %matplotlib inline
import os
import sympy
from beambending.beam import *
x = sympy.symbols("x")  # uncomment if you use variable distributed loads


# Go on and play around with the values in this section. See what happens!
beam = Beam(9)
beam.fixed_support = 2    # x-coordinate of the fixed support
beam.rolling_support = 7  # x-coordinate of the rolling support
beam.add_loads((
                PointLoadV(-20, 3),  # 20kN downwards, at x=3m
                PointLoadH(15, 8),  # towarde the right, at x=9m
                DistributedLoadV(-10, (3, 9)),  # 10 kN/m, downward, for 3m <= x <= 9m
                DistributedLoadV(-20, (0, 2)),  # 20 kN/m downwards, for 0m <= x <= 2m
))

# Output generation (leave this section as it is, unless you know what you are doing)
fig = beam.plot()
fig.savefig("./beamtest.pdf")

# %% [markdown]
# Click the link to download [a pdf file with your case results](./beamtest.pdf "Come on and click! You know you want to.").

# %% [markdown]
# You can now go back up and continue to play around choosing different loads, beam lengths and placement of the beam supports.
# Add as many loads as you want to the list (but don't forget to put a comma between two loads).
#
# After you have made some changes, run the code cell again to calculate your new results.
#
# When you are comfortable with that, check what happens if you try more interesting expressions for the distributed loads, for example:
#
# ```python
# DistributedLoadV("2 * x**2 + 5", (0, 3))
# ```
# (by the way, a double asterisk is how you write a power in python: ```"2 * x**2 + 5"``` means $2x^2 + 5$)
#
# **Note:** the quotation marks around mathematical expressions are optional.
